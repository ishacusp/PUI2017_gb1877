# %%
from __future__ import print_function
__author__ = "Gaurav Bhardwaj, CUSP NYU 2017"

# %% [markdown]
# Create a reproducible research chunk of code
# That means we want the reader to be able to reproduce every step of the work we do.
# If our work includes the use of stochastic processes and random variables that gets tricky: how do we assure the random draw gives the same number to the user that it gave to me? That is not random!
# That becomes possible because computers are unable to poduce truly random numbers. When we ask a computer to generate a random number, it will in fact generate a "pseudo random" number. The number will be randon in the sanse that it will be some number between, for example, 0 and 1 if we ask for a uniform random distribution or a number near 0 if we aks for a Gaussian distribution with mean 0. But the sequence of pseudo-random numbers that a compujter generates will depend on its **seed**: if you know the seed you know all the numbers that are "randomely" drawn.
# You can read more about pseudorandom number generation in this wikipedia article https://en.wikipedia.org/wiki/Pseudorandom_number_generator
# Fill in the empty cells below with code, as directed.

# %%
import os
import sys

# you can use the numpy library for random number generation: 
# http://docs.scipy.org/doc/numpy/reference/routines.random.html

import numpy as np

# %% [markdown]
# THIS IS THE MOST IMPORTANT PIECE OF THIS CODE!
#
# give numpy as seed for this code to be reproducible
#
# (no points if this is wrong)
#
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.seed.html

# %%
np.random.seed(90)

# %% [markdown]
# 1. Generate random distributions.
#
# use the function
#
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.randn.html
#
# to generate 100 2-dimensional random datapoints in a gaussian distribution
#
# call the array ReprRand

# %%
def ReprRand():
    for i in range(1,100):
        np.random.randn(i)
        reprRand=np.random.randn(2,100)
    return reprRand

# %%
ReprRand()
# Out:
# array([[ -2.71283194e-01,   3.73775814e-01,  -2.71254787e+00,
#          -9.98744278e-01,  -8.10581450e-02,  -1.80123053e+00,
#           1.12969887e-01,  -4.09062400e-02,   1.00966690e+00,
#           1.39455061e-01,  -8.73987180e-01,   1.03550040e-02,
#           2.02146407e+00,   4.04526521e-01,  -7.93739117e-01,
#          -1.74973251e+00,  -3.68915646e-01,  -2.85222597e-01,
#          -2.59955565e+00,  -6.40369734e-01,  -6.67059899e-01,
#           7.99219084e-01,   1.11309765e-02,   2.15123242e+00,
#          -5.63281165e-01,  -3.27034498e-01,   1.66968209e+00,
#           1.14277019e+00,  -3.84429101e-01,   1.03071958e+00,
#          -7.55415314e-02,   2.50252067e+00,   1.41431537e-01,
#          -1.37276819e-01,   2.62046599e-01,   3.38552276e-01,
#           2.33649405e-01,   3.87998914e-01,   8.38316439e-01,
#           4.69691222e-01,  -1.98769929e-01,   1.28028135e-01,
#           7.77854164e-01,  -1.73698258e+00,   8.06308170e-01,
# ...

# %% [markdown]
# 2. use the same function to generate 50 more random 2x100 numpy arrays and store them in ReprRandAll, all with different mean.
#
# np.random.randn creates a distribution with mean 0 and standard deviation 1 by default.
#
# To obtain a gaussian distribution with a mean different than 1 using np.random.randn you must add your new mean (it is explained in the dunction documentation for which I already gave you the link)
#
# If you want to change the standard deviation (sigma) as well you multiply the distribution by the new sigma.
#
# You can do it in a for loop. The first line of code I included generates an array of zeros that you can fill in with your new numbers.

# %%
def ReprRand():
    global reprRandAll
    reprRandAll=np.zeros((50,2,100))
    staDev=5
    mean=50
    
    for i in range(50):
        np.random.randn(i)
        reprRandAll[i]=staDev*np.random.randn(2,100)+mean
        i+=1
    return reprRandAll

# %%
ReprRand()
# Out:
# array([[[ 52.52682751,  57.54975313,  46.43400801, ...,  47.54808442,
#           46.66830251,  50.14780765],
#         [ 41.00509411,  51.8749669 ,  51.67641588, ...,  49.20068784,
#           52.24740863,  44.45757713]],
#
#        [[ 43.50249778,  51.09930015,  50.56823126, ...,  50.03343184,
#           56.19881772,  57.82091128],
#         [ 57.0227543 ,  49.92688133,  46.48496815, ...,  46.20418881,
#           52.6233538 ,  51.86222331]],
#
#        [[ 59.27517878,  43.80914453,  51.98698895, ...,  58.15437701,
#           49.47742929,  49.78311568],
#         [ 57.34204663,  54.71668332,  59.56225071, ...,  57.42989743,
#           50.72489878,  44.95565972]],
#
#        ...,
#        [[ 54.20510096,  50.19487211,  50.51169257, ...,  52.50995681,
#           51.01130773,  51.38675881],
#         [ 48.20723625,  50.32325337,  50.23463758, ...,  47.63841404,
#           52.02426904,  55.80899047]],
#
#        [[ 50.66613337,  54.62337221,  54.40994931, ...,  48.56215658,
# ...

# %%
reprRandAll.shape
# Out:
# (50, 2, 100)

# %% [markdown]
# 3. now plot them:
#
# you can use the matplotlib library, and the function scatter(), but that would plot everything in the same color unless you ask it not to.
#
# For convenience, let's use the function plot() which by default plots lines, and tell it to plot points (in addition plot is actually more efficient, so if you have a large dataset you may want to consider using plot with points for it anyways)
#
# https://scipy-lectures.github.io/intro/matplotlib/matplotlib.html#scatter-plots
#
# http://matplotlib.org/users/pyplot_tutorial.html

# %%
import pylab as pl
import pandas as pd
# %pylab inline
# the last line of code makes the plot show up within the notebook. 
# Always include it so that your homework notebooks are rendered and we can see
# what you wanted your results to be. 

for i in range(len(reprRandAll)):
    for j in range(len(reprRandAll)):
        pl.plot(reprRandAll[i][0][j],reprRandAll[i][1][j],'.')

pl.xlabel('Distribution across x-axis')
pl.ylabel('Distribution across y-axis')
pl.title('Random distribution of numbers')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Always add a caption to each of your homework figures. And remember to give your labels some names! This is a general rule. Without the caption or axis labels this portion of the HW will not get points. Make sure the font in the labels is large enough to be readable.

# %%
import pylab as pl
import pandas as pd
# %pylab inline
# the last line of code makes the plot show up within the notebook. 
# Always include it so that your homework notebooks are rendered and we can see
# what you wanted your results to be. 

for i in range(len(reprRandAll)):
    for j in range(len(reprRandAll)):
        pl.plot(reprRandAll[i][0][j],reprRandAll[i][1][j],'.')

pl.xlabel('Distribution across x-axis')
pl.ylabel('Distribution across y-axis')
pl.title('Random distribution of numbers')
pl.text(30,20,'This is the representation of numbers randomly with variable mean and standard deviation')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Challenge
#
# It is easier to give the same mean and standard deviation to each dimension. Can you give two different values for the mean along the x- and the mean along the y- axis for each of the 50 distributions if you have not done so? If you are an experienced coder, can you do it in a single line?

# %%
import pylab as pl
import pandas as pd
# %pylab inline
# the last line of code makes the plot show up within the notebook. 
# Always include it so that your homework notebooks are rendered and we can see
# what you wanted your results to be. 

meanX=-40
meanY=25
statDevX=4
statDevY=3

for i in range(len(reprRandAll)):
    for j in range(len(reprRandAll)):
        pl.plot(statDevX*reprRandAll[i][0][j]+meanX,statDevY*reprRandAll[i][1][j]+meanY,'.')

pl.xlabel('Distribution across x-axis')
pl.ylabel('Distribution across y-axis')
pl.title('Random distribution of numbers')
pl.text(80,90,'This is the representation of numbers randomly with variable mean and standard deviation')
# Out:
# Populating the interactive namespace from numpy and matplotlib
